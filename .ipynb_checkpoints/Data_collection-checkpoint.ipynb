# %% [markdown]
# # Generate ticket data for upcoming concerts

# %% [markdown]
# Pulls data from 3 main sources: <br>
# <ul>
# <li>Stubhub.com API</li>
# <li>SongKick.com</li>
# <li>EchoNest.com API</li>
# </ul>
# <br>Assume almost all ticket prices (from both StubHub and SongKick) include relevant fees. Prices should be interpreted as what the concertgoer actually pays. <br>

# %%
import datetime
import json
import numpy as np
import os
import pandas as pd
import re
import requests
import time
from bs4 import BeautifulSoup

# %% [markdown]
# ## Define Functions

# %%
# GetEventsNearCity - returns info about events near a given city 
# Gives us everything except face value and ticket vendor info.
# Reference: https://developer.stubhub.com/store/site/pages/doc-viewer.jag?category=Search&api=EventSearchAPIv2&endpoint=searchforeventsv2&version=v2
def GetStubHubEventsNearCity(city, limit):
    url = 'https://api.stubhub.com/search/catalog/events/v2'
    query = {'city': city, 'minAvailableTickets':1, 'categoryName':'Concert tickets', 'limit': limit}
    headers = {'Authorization': 'Bearer **API_KEY_HERE**'} # Insert StubHub API Key here
    r = requests.get(url, params=query, headers=headers, verify=True)
    df = CreateStubHubDataFrame(r)
    return df

def CreateStubHubDataFrame(stubhub_response):
    json_response = json.loads(stubhub_response.text)
    event_info = []
    for event in json_response['events']:
        if 'attributes' in event:
            # If the event data has the attributes key (it sometimes doesn't):
            event_info.append(
                {
                    'artist':event['attributes'][0].get('value').encode('utf-8', errors='replace'),
                    'date':str(event['dateLocal']),
                    'event_id':str(event['id']),
                    'min_price':str(event['ticketInfo'].get('minPrice')),
                    'max_price':str(event['ticketInfo'].get('maxPrice')),
                    'total_postings':str(event['ticketInfo'].get('totalPostings')),
                    'total_tickets':str(event['ticketInfo'].get('totalTickets')),
                    'venue':str(event['venue'].get('name')),
                    'city':str(event['venue'].get('city')),
                    'state':str(event['venue'].get('state')),
                }
            )
    sort_map = ['event_id', 'date', 'artist', 'venue', 'min_price', 'max_price', 'total_postings', 'total_tickets', 'city', 'state']
    TicketData = pd.DataFrame(event_info)
    TicketData = TicketData.ix[:, sort_map] # sort columns based on sort map
    TicketData = TicketData.sort_values(by='event_id', ascending=True)
    return TicketData

def DeleteNonConcerts(df):
    df = df[df['artist'].str.contains("PARKING PASSES") == False] # Get rid of parking pass tix
    df = df[df['venue'].str.contains("111 Minna Gallery") == False] # Hard-coded for SF (art gallery)
    df = df[df['artist'].str.contains("STRAWBERRY FIELDS") == False] # Get rid of STRAWBERRY FIELDS at BB King's Blues Club NYC
    df = df.reset_index() # reset numeric index
    del df['index']
    return df

def GenerateArtistVenueListFromDataframe(df):
    original_artist_venue_list = df[['event_id', 'artist', 'venue']].values.tolist()
    filtered_artist_venue_list = []
    # Send artist venue list items thru filter to correct bad values before SongKick query:
    for item in original_artist_venue_list:
        item = FilterArtistVenueList(item)
        filtered_artist_venue_list.append(item)
    #artist_venue_list = artist_venue_list[:210] # Limit list just for testing purposes.
    return filtered_artist_venue_list
    
# FilterArtistVenueList - for a list of form [event_id, artist, venue], run filters on values to prepare for SongKick
def FilterArtistVenueList(artist_venue_list):
    artist_venue_list[2] = artist_venue_list[2].replace('Nob Hill Masonic Auditorium', 'Masonic')
    artist_venue_list[2] = artist_venue_list[2].replace("Slims", "Slim's")
    artist_venue_list[2] = artist_venue_list[2].replace("Ruby Skye Nightclub", 'Ruby Skye')
    artist_venue_list[2] = artist_venue_list[2].replace("Bimbos 365 Club", "Bimbo's 365 Club")
    artist_venue_list[2] = artist_venue_list[2].replace("Stubbs BarBQ", "Stubb's BBQ")
    artist_venue_list[2] = artist_venue_list[2].replace("Emos", "Emo's")
    artist_venue_list[2] = artist_venue_list[2].replace("Frank Erwin Events Center", "Frank Erwin Center")
    artist_venue_list[2] = artist_venue_list[2].replace("ACL Live at The Moody Theater", "Austin City Limits Live at The Moody Theater")
    artist_venue_list[2] = artist_venue_list[2].replace("El Rey Theatre (LA)", "El Rey Theatre")
    artist_venue_list[2] = artist_venue_list[2].replace("Wiltern Theatre", "The Wiltern")
    artist_venue_list[1] = artist_venue_list[1].replace("HARLEM GOSPEL CHOIR", "Jessica Carvo")
    return artist_venue_list

# SongKickArtistVenueSearch - for a given query (artist + venue), give us the Songkick search results page
def SongKickArtistVenueSearch(query):
    url = 'http://www.songkick.com/search'
    parameters = {'page':'1', 'per_page':'10', 'query':query, 'type':'upcoming'}
    r = requests.get(url, params=parameters)
    return r

# GetSongKickEventPage - for a given SongKick event URL tail, return the SongKick event HTML page
def GetSongKickEventPage(url_tail):
    base_url = 'http://www.songkick.com'
    full_url = base_url + url_tail
    r = requests.get(full_url)
    return r

# ConvertDateStringToDateTime - for a given date string (formatted by StubHub API), return a date object for date
def ConvertDateStringToDateTime(date_string):
    date_string = date_string.replace('T', '')[:-13].upper() # Get rid of time from date string.
    date_string = date_string.replace('-', ' ') # Get rid of dashes.
    date_time = datetime.datetime.strptime(date_string, "%Y %m %d")
    date = date_time.date()
    return date

# GetNumberOfDaysUntilDate - for a given date string (formatted by StubHub API), get the number of days from now until then
def GetNumberOfDaysUntilDate(date_string):
    date = ConvertDateStringToDateTime(date_string)
    now = datetime.datetime.now().date()
    delta = date - now
    return delta.days

# GetEchonestRateLimit - returns our current Echonest API rate limit (i.e., number of allowed calls per minute)
# http://developer.echonest.com/docs/v4#rate-limits
def GetEchonestRateLimit():
    url = 'http://developer.echonest.com/api/v4/artist/profile?api_key=**API_KEY_HERE**&name=radiohead'
    r = requests.get(url, verify=True)
    rate_limit = int(r.headers['X-RateLimit-Limit'])
    return rate_limit

# GetEchonestInfo function - for a given SongKick Artist ID string, return a list with the relevant Echonest Info for the artist
# Return list is of the form: [SK_id, # blogs, # news, # reviews, discovery, famliliarity, hotttnesss, # years active]
def GetEchonestInfo(sk_id):
    url = ("http://developer.echonest.com/api/v4/artist/profile?api_key=**API_KEY_HERE**&id=songkick:artist:"+sk_id+
            "&bucket=familiarity&bucket=hotttnesss&bucket=discovery&bucket=years_active&bucket=doc_counts")
    r = requests.get(url) #get data
    json_response = json.loads(r.text) #put data into json object
    if json_response['response']['status']['code'] == 0:
        # if we received valid results from echonest for the given ID:
        i = json_response['response']['artist']
    
        # convert the year in years_active to number of years active
        if i['years_active'] and (type(i['years_active'][0]['start']) is int): # if the years_active list is not empty    
            start_year = datetime.date(i['years_active'][0]['start'],1,1).year
            this_year = datetime.date(datetime.date.today().year,1,1).year
            num_years_active = this_year - start_year
        else:
            num_years_active = None

        info_list = [sk_id, i['doc_counts']['blogs'], i['doc_counts']['news'], i['doc_counts']['reviews'], 
                     i['discovery'], i['familiarity'], i['hotttnesss'], num_years_active]
    else:
        # if echonest returned a non-success response code (see here: http://developer.echonest.com/docs/v4#response-codes):
        error = "error_"+str(json_response['response']['status']['code'])
        info_list = [sk_id, error, error, error, error, error, error, error]
    return info_list

# %% [markdown]
# ## Create StubHub Dataframe for a given metro area and get rid of non-concert events

# %%
city = 'Portland' # Set Desired Metro Area Here
file_suffix = "POR" # Hard code for output file suffixes

# Get Stubhub events for a given city and put resulting events data into TicketData dataframe
TicketData = GetStubHubEventsNearCity(city, 500)

print "Data count: "
print TicketData['event_id'].count()
TicketData.head()
# Out:
# Data count:
# 214
#     event_id                      date         artist  \
# 47   9152782  2016-05-17T20:30:00-0700        The Who
# 102  9352311  2016-07-03T20:00:00-0700  Janet Jackson
# 168  9367549  2016-04-14T20:00:00-0700  Gary Clark Jr
# 126  9372111  2016-03-14T20:00:00-0700      Disturbed
# 190  9381633  2016-03-31T19:30:00-0700      Underoath
#
#                                venue min_price max_price total_postings  \
# 47   Moda Center at the Rose Quarter     68.17     902.0             58
# 102  Moda Center at the Rose Quarter      55.6     500.0            124
# 168                 Roseland Theater     74.26    199.88             30
# 126                 Roseland Theater     77.82   5555.55             14
# 190      McMenamins Crystal Ballroom     57.83     199.0             10
#
#     total_tickets      city state
# 47          170.0  Portland    OR
# 102         371.0  Portland    OR
# 168         128.0  Portland    OR
# 126          63.0  Portland    OR
# 190          70.0  Portland    OR

# %%
# Get rid of rows that aren't actually concerts
TicketData = DeleteNonConcerts(TicketData)

print "New data count: "
print TicketData['event_id'].count()
TicketData.head()
# Out:
# New data count:
# 207
#   event_id                      date         artist  \
# 0  9152782  2016-05-17T20:30:00-0700        The Who
# 1  9352311  2016-07-03T20:00:00-0700  Janet Jackson
# 2  9367549  2016-04-14T20:00:00-0700  Gary Clark Jr
# 3  9372111  2016-03-14T20:00:00-0700      Disturbed
# 4  9381633  2016-03-31T19:30:00-0700      Underoath
#
#                              venue min_price max_price total_postings  \
# 0  Moda Center at the Rose Quarter     68.17     902.0             58
# 1  Moda Center at the Rose Quarter      55.6     500.0            124
# 2                 Roseland Theater     74.26    199.88             30
# 3                 Roseland Theater     77.82   5555.55             14
# 4      McMenamins Crystal Ballroom     57.83     199.0             10
#
#   total_tickets      city state
# 0         170.0  Portland    OR
# 1         371.0  Portland    OR
# 2         128.0  Portland    OR
# 3          63.0  Portland    OR
# 4          70.0  Portland    OR

# %% [markdown]
# ## Create List of Artist-Venue Pairs (for searching SongKick)

# %%
# Generate list of artist-venue pairs from StubHub data to search on SongKick to get ticket info for each event.
artist_venue_list = GenerateArtistVenueListFromDataframe(TicketData)
print artist_venue_list
# Out:
# [['9152782', 'The Who', 'Moda Center at the Rose Quarter'], ['9352311', 'Janet Jackson', 'Moda Center at the Rose Quarter'], ['9367549', 'Gary Clark Jr', 'Roseland Theater'], ['9372111', 'Disturbed', 'Roseland Theater'], ['9381633', 'Underoath', 'McMenamins Crystal Ballroom'], ['9395359', '2Cellos', 'Keller Auditorium'], ['9411823', 'Ciara', 'Roseland Theater'], ['9415018', 'Leon Bridges', 'Arlene Schnitzer Hall'], ['9425581', "Umphrey's McGee", 'McMenamins Crystal Ballroom'], ['9425627', 'Demi Lovato and Nick Jonas', 'Moda Center at the Rose Quarter'], ['9426932', 'Twenty One Pilots', 'Moda Center at the Rose Quarter'], ['9432568', 'Ellie Goulding', 'Moda Center at the Rose Quarter'], ['9434937', 'Bonnie Raitt', 'Keller Auditorium'], ['9438924', 'Celtic Woman', 'Arlene Schnitzer Hall'], ['9439488', 'Maroon 5', 'Moda Center at the Rose Quarter'], ['9440727', 'Anders Osborne', 'Dantes'], ['9443411', 'Finish Ticket', 'McMenamins Crystal Ballroom'], ['9445590', 'Justin Bieber', 'Moda Center at the Rose Quarter'], ['9452592', 'Daughter', 'Wonder Ballroom'], ['9453413', 'Lake Street Dive', 'State Theatre Portland Maine'], ['9456682', 'Jukebox the Ghost', 'Port City Music Hall'], ['9457937', 'Phil Cook', 'Doug Fir Lounge '], ['9457939', 'Greg Dulli', 'Doug Fir Lounge '], ['9457940', 'Polica', 'Doug Fir Lounge '], ['9457941', 'Polica', 'Doug Fir Lounge '], ['9457942', 'Field Music', 'Doug Fir Lounge '], ['9457946', 'Judah and The Lion', 'Doug Fir Lounge '], ['9459803', 'Arlo Guthrie', 'Revolution Hall Portland'], ['9459856', 'Loreena McKennitt', 'Arlene Schnitzer Hall'], ['9461064', 'Percy Hill', 'Port City Music Hall'], ['9462423', 'Wolfmother', 'Wonder Ballroom'], ['9463096', 'Rachel Platten', 'Wonder Ballroom'], ['9465904', 'Breaking Benjamin', 'Roseland Theater'], ['9468498', 'Joanna Newsom', 'Arlene Schnitzer Hall'], ['9468976', 'The Melvins and Napalm Death', 'Roseland Theater'], ['9469543', 'Slayer', 'Roseland Theater'], ['9469802', 'The 1975', 'Arlene Schnitzer Hall'], ['9470756', 'Mac DeMarco', 'Roseland Theater'], ['9470917', 'Nada Surf', 'Doug Fir Lounge '], ['9474191', 'Yonder Mountain String Band', 'McMenamins Crystal Ballroom'], ['9475465', 'Peter Frampton', 'Revolution Hall Portland'], ['9476550', 'King Gizzard And The Lizard Wizard', 'Mississippi Studios'], ['9477146', 'The Mountain Goats', 'Port City Music Hall'], ['9478034', 'Mac DeMarco', 'Roseland Theater'], ['9483194', 'Blue October', 'Roseland Theater'], ['9483670', 'X Ambassadors', 'McMenamins Crystal Ballroom'], ['9483958', 'Ra Ra Riot', 'Revolution Hall Portland'], ['9484056', 'Mayday Parade', 'State Theatre Portland Maine'], ['9484101', 'San Fermin', 'Mississippi Studios'], ['9484975', 'Dark Star Orchestra', 'McMenamins Crystal Ballroom'], ['9484976', 'Dark Star Orchestra', 'McMenamins Crystal Ballroom'], ['9485299', 'The Milk Carton Kids', 'State Theatre Portland Maine'], ['9485369', 'Dream Theater', 'Arlene Schnitzer Hall'], ['9486475', 'Puscifer', 'Merrill Auditorium'], ['9486595', 'Brian Wilson performs Pet Sounds', 'Merrill Auditorium'], ['9486816', 'Tech N9ne', 'Roseland Theater'], ['9488874', 'The Expendables', 'Asylum Maine'], ['9489290', 'Sharon Jones & The Dap Kings', 'Keller Auditorium'], ['9490629', 'Richard Cheese', 'McMenamins Crystal Ballroom'], ['9491372', 'Deer Tick', 'Port City Music Hall'], ['9491373', 'Enter The Haggis', 'Port City Music Hall'], ['9491374', 'Ezra Furman', 'Port City Music Hall'], ['9491375', 'Maine Youth Rock Orchestra', 'Port City Music Hall'], ['9491768', 'Between the Buried and Me & August Burns Red', 'State Theatre Portland Maine'], ['9491796', 'Between the Buried and Me and August Burns Red', 'Roseland Theater'], ['9500582', 'White Denim', 'Doug Fir Lounge '], ['9500655', 'George Clinton and the Parliament Funkadelic', 'McMenamins Crystal Ballroom'], ['9500935', 'Courtney Barnett', 'McMenamins Crystal Ballroom'], ['9501172', 'Miike Snow', 'Roseland Theater'], ['9501270', 'Parachute', 'Port City Music Hall'], ['950174 ...

# %% [markdown]
# ## Get SongKick Event URLs

# %%
# Get Songkick event URLs for each event from the StubHub data (TIME CONSUMING FOR LARGE DATASETS)
sk_eventURL_list = []
for item in artist_venue_list:
    query = str(item[1]) + " " + str(item[2]) # "Artist Venue"
    response = SongKickArtistVenueSearch(query)
    soup = BeautifulSoup(response.text, 'html.parser')
    results = soup.find_all("p", class_="summary")
    if results:
        m = re.search("/concerts/[0-9]{8}[a-zA-Z-]*", str(results[0])) # Only look at first result.
        if m:
            to_append = [item[0], m.group(0)]
        else:
            # If there were SongKick search results for the query but we didn't find anything matching the above regex.
            # This can happen when the results of the search are festivals - example of such a URL below:
            # http://www.songkick.com/festivals/647839-boston-calling-music/id/25083139-boston-calling-music-festival-2016
            to_append = [item[0], 'NoRegexp'] 
    else:
        to_append = [item[0], 'NoResults']
    sk_eventURL_list.append(to_append)
    time.sleep(0.5) # Wait half a second (so that we don't send too many requests to SongKick to fast)

print sk_eventURL_list
# Out:
# [['9152782', '/concerts/25121519-who-at-moda-center-at-the-rose-quarter'], ['9352311', '/concerts/25889688-janet-jackson-at-moda-center-at-the-rose-quarter'], ['9367549', '/concerts/24556084-gary-clark-jr-at-roseland-theater'], ['9372111', '/concerts/24648129-disturbed-at-roseland-theater'], ['9381633', 'NoResults'], ['9395359', '/concerts/24918589-'], ['9411823', '/concerts/25412664-ciara-at-roseland-theater'], ['9415018', '/concerts/25150829-leon-bridges-at-arlene-schnitzer-concert-hall'], ['9425581', 'NoResults'], ['9425627', '/concerts/25372244-demi-lovato-at-moda-center-at-the-rose-quarter'], ['9426932', '/concerts/25262254-twenty-one-pilots-at-moda-center-at-the-rose-quarter'], ['9432568', '/concerts/25317159-ellie-goulding-at-moda-center-at-the-rose-quarter'], ['9434937', '/concerts/25325134-bonnie-raitt-at-keller-auditorium'], ['9438924', '/concerts/25332184-celtic-woman-at-arlene-schnitzer-concert-hall'], ['9439488', '/concerts/25362449-maroon-'], ['9440727', 'NoResults'], ['9443411', 'NoResults'], ['9445590', 'NoResults'], ['9452592', '/concerts/25384099-daughter-at-wonder-ballroom'], ['9453413', '/concerts/25410094-lake-street-dive-at-state-theatre'], ['9456682', '/concerts/25447659-jukebox-the-ghost-at-port-city-music-hall'], ['9457937', '/concerts/25402059-phil-cook-at-doug-fir-lounge'], ['9457939', '/concerts/25242499-greg-dulli-at-doug-fir-lounge'], ['9457940', '/concerts/25421119-polica-at-doug-fir-lounge'], ['9457941', '/concerts/25421119-polica-at-doug-fir-lounge'], ['9457942', '/concerts/25154484-field-music-at-doug-fir-lounge'], ['9457946', '/concerts/25438319-judah-and-the-lion-at-doug-fir-lounge'], ['9459803', '/concerts/25438264-arlo-guthrie-at-revolution-hall'], ['9459856', '/concerts/25380474-loreena-mckennitt-at-arlene-schnitzer-concert-hall'], ['9461064', '/concerts/25390754-percy-hill-at-port-city-music-hall'], ['9462423', '/concerts/25478699-wolfmother-at-wonder-ballroom'], ['9463096', '/concerts/25504424-rachel-platten-at-wonder-ballroom'], ['9465904', '/concerts/25527589-breaking-benjamin-at-roseland-theater'], ['9468498', '/concerts/25630434-joanna-newsom-at-arlene-schnitzer-concert-hall'], ['9468976', '/concerts/25583799-melvins-at-roseland-theater'], ['9469543', '/concerts/25583954-slayer-at-roseland-theater'], ['9469802', '/concerts/25574024-'], ['9470756', '/concerts/25626149-mac-demarco-at-roseland-theater'], ['9470917', '/concerts/25566089-nada-surf-at-doug-fir-lounge'], ['9474191', 'NoResults'], ['9475465', '/concerts/25602259-peter-frampton-at-revolution-hall'], ['9476550', '/concerts/25415959-king-gizzard-and-the-lizard-wizard-at-mississippi-studios'], ['9477146', '/concerts/25612829-mountain-goats-at-port-city-music-hall'], ['9478034', '/concerts/25626149-mac-demarco-at-roseland-theater'], ['9483194', '/concerts/25650094-blue-october-at-roseland-theater'], ['9483670', 'NoResults'], ['9483958', '/concerts/25593959-ra-ra-riot-at-revolution-hall'], ['9484056', '/concerts/25668089-maine-at-state-theatre'], ['9484101', '/concerts/25666344-san-fermin-at-mississippi-studios'], ['9484975', 'NoResults'], ['9484976', 'NoResults'], ['9485299', '/concerts/25613149-milk-carton-kids-at-state-theatre'], ['9485369', '/concerts/25690494-dream-theater-at-arlene-schnitzer-concert-hall'], ['9486475', '/concerts/25730484-puscifer-at-merrill-auditorium-portland-city-hall'], ['9486595', 'NoResults'], ['9486816', '/concerts/25736204-tech-n'], ['9488874', 'NoResults'], ['9489290', '/concerts/25615274-sharon-jones-and-the-dapkings-at-keller-auditorium'], ['9490629', 'NoResults'], ['9491372', '/concerts/25589984-deer-tick-at-port-city-music-hall'], ['9491373', '/concerts/25674084-enter-the-haggis-at-port-city-music-hall'], ['9491374', '/concerts/25563824-ezra-furman-at-port-city-music-hall'], ['9491375', '/concerts/25768299-maine-youth-rock-orchestra-at-port-city-music-hall'], ['9491768', '/concerts/25798589-between-the-buried-and-me-at-state-theatre'], ['9491796', '/concerts/25813144-between-the-buried-and-me-a ...

# %% [markdown]
# ## Check SongKick URL Results and write list to a txt file as a backup

# %%
# Check to see which events did not get SongKick results
sk_eventURL_list_df = pd.DataFrame(sk_eventURL_list, columns=('event_id', 'sk_result'))
no_sk_results_df = sk_eventURL_list_df[sk_eventURL_list_df['sk_result'] == "NoResults"]
no_sk_results_df = sk_eventURL_list_df.join(TicketData, how='inner', rsuffix='_noSK')

num_events = len(sk_eventURL_list)
missing_events = no_sk_results_df[no_sk_results_df['sk_result'] == "NoResults"]['venue'].count()

print("Total # of events: \n%d" % num_events)
print("Total number of missing events: \n%d" % missing_events) 
print "\nVenues missing data:"
print no_sk_results_df[no_sk_results_df['sk_result'] == "NoResults"]['venue'].value_counts() #check artists
# Out:
# Total # of events:
# 207
# Total number of missing events:
# 50
#
# Venues missing data:
# McMenamins Crystal Ballroom        21
# Thompsons Point                     7
# Roseland Theater                    4
# Hawthorne Theatre                   3
# Dantes                              3
# Moda Center at the Rose Quarter     2
# Maine State Pier                    2
# Holocene                            1
# Wonder Ballroom                     1
# Port City Music Hall                1
# Doug Fir Lounge                     1
# Cross Insurance Arena               1
# Asylum Maine                        1
# Merrill Auditorium                  1
# Arlene Schnitzer Hall               1
# Name: venue, dtype: int64

# %%
# Write sk_eventURL_list to a text file in case we need to come back to it.
sk_url_list_file = open('Mid_Pipeline_Data/SongKickURLList_'+file_suffix+'.txt', 'w')
for item in sk_eventURL_list:
    print>>sk_url_list_file, item
print "\nBackup file written."
# Out:
# Backup file written.

# %% [markdown]
# ## Get Ticket Information from SongKick URLs

# %%
# Generate a new DataFrame with Ticket face value info for each event. (TIME CONSUMING FOR LARGE DATASETS)
event_face_value_list = []
for event in sk_eventURL_list:
    if (event[1] == "NoResults") | (event[1] == "NoRegexp"):
        # If we didn't get a URL tail, append "NoResults" and move to the next item in the for loop.
        event_face_value_list.append([event[0], event[1], event[1], event[1], event[1]])
        continue
    event_info = [event[0]] # Add Stubhub event ID to event_info list
    print event
    response = GetSongKickEventPage(event[1])
    soup = BeautifulSoup(response.text, 'html.parser')
    
    # Get ticket vendor data.
    vendors = soup.find_all("span", class_="vendor")
    if vendors:
        vendor_string = str(vendors[0])
        vendor_string = vendor_string.replace('<span class="vendor">', "")
        vendor_string = vendor_string.replace('\n      </span>', '')
    else:
        vendor_string = "NoVendorClass"
    event_info.append(vendor_string)

    #Get face value for tickets according to SongKick
    price = soup.find_all("span", class_="price")
    if price:
        m = re.search("\$[0-9.]*", str(price[0])) # NOTE - this will get the minimum ticket price if there is a range.
        if m:
            price = m.group(0)
        else:
            price = "NoPriceNumber"
    else:
        price = "NoPriceClass"
    event_info.append(price)
    
    #Get ticket availability status (0 for still available, 1 for Sold Out)
    status = soup.find_all("div", class_="ticket-cell buy-button-container")
    if status:
        m = re.search("sold-out", str(status[0]))
        if m:
            status = 1 # Sold out.
        else:
            status = 0 # Not sold out.
    else:
        status = "NoSoldOutClass"
    event_info.append(status)
    
    #Get SongKick artist ID for artist
    artist_id = soup.find_all("h1", class_="summary")
    if artist_id:
        m = re.search("/artists/[0-9]{3,9}", str(artist_id[0])) # assume that a SK artist ID is between 3 and 8 #'s long
        if m:
            artist_id = m.group(0)
            artist_id = artist_id.replace('/artists/', '')
        else:
            artist_id = "NoArtistID"
    else:
        artist_id = "NoArtistIDClass"
    event_info.append(artist_id)
    
    
    event_face_value_list.append(event_info)
    time.sleep(0.5) # Wait half a second (so that we don't send too many requests to SongKick to fast)

FaceValue_df = pd.DataFrame(event_face_value_list, columns=['event_id', 'ticket_vendor', 'face_value', 'sold_out', 'sk_artist_id'])
FaceValue_df.head()
# Out:
# ['9152782', '/concerts/25121519-who-at-moda-center-at-the-rose-quarter']
# ['9352311', '/concerts/25889688-janet-jackson-at-moda-center-at-the-rose-quarter']
# ['9367549', '/concerts/24556084-gary-clark-jr-at-roseland-theater']
# ['9372111', '/concerts/24648129-disturbed-at-roseland-theater']
# ['9395359', '/concerts/24918589-']
# ['9411823', '/concerts/25412664-ciara-at-roseland-theater']
# ['9415018', '/concerts/25150829-leon-bridges-at-arlene-schnitzer-concert-hall']
# ['9425627', '/concerts/25372244-demi-lovato-at-moda-center-at-the-rose-quarter']
# ['9426932', '/concerts/25262254-twenty-one-pilots-at-moda-center-at-the-rose-quarter']
# ['9432568', '/concerts/25317159-ellie-goulding-at-moda-center-at-the-rose-quarter']
# ['9434937', '/concerts/25325134-bonnie-raitt-at-keller-auditorium']
# ['9438924', '/concerts/25332184-celtic-woman-at-arlene-schnitzer-concert-hall']
# ['9439488', '/concerts/25362449-maroon-']
# ['9452592', '/concerts/25384099-daughter-at-wonder-ballroom']
# ['9453413', '/concerts/25410094-lake-street-dive-at-state-theatre']
# ['9456682', '/concerts/25447659-jukebox-the-ghost-at-port-city-music-hall']
# ['9457937', '/concerts/25402059-phil-cook-at-doug-fir-lounge']
# ['9457939', '/concerts/25242499-greg-dulli-at-doug-fir-lounge']
# ['9457940', '/concerts/25421119-polica-at-doug-fir-lounge']
# ['9457941', '/concerts/25421119-polica-at-doug-fir-lounge']
# ['9457942', '/concerts/25154484-field-music-at-doug-fir-lounge']
# ['9457946', '/concerts/25438319-judah-and-the-lion-at-doug-fir-lounge']
# ['9459803', '/concerts/25438264-arlo-guthrie-at-revolution-hall']
# ['9459856', '/concerts/25380474-loreena-mckennitt-at-arlene-schnitzer-concert-hall']
# ['9461064', '/concerts/25390754-percy-hill-at-port-city-music-hall']
# ['9462423', '/concerts/25478699-wolfmother-at-wonder-ballroom']
# ['9463096', '/concerts/25504424-rachel-platten-at-wonder-ballroom']
# ['9465904', '/concerts/25527589-breaking-benjamin-at-roseland-theater']
# ['9468498', '/concerts/25630434-joanna-newsom-at-arlene-schnitzer-concert-hall']
# ['9468976', '/concerts/25583799-melvins-at-roseland-theater']
# ['9469543', '/concerts/25583954-slayer-at-roseland-theater']
# ['9469802', '/concerts/25574024-']
# ['9470756', '/concerts/25626149-mac-demarco-at-roseland-theater']
# ['9470917', '/concerts/25566089-nada-surf-at-doug-fir-lounge']
# ['9475465', '/concerts/25602259-peter-frampton-at-revolution-hall']
# ['9476550', '/concerts/25415959-king-gizzard-and-the-lizard-wizard-at-mississippi-studios']
# ['9477146', '/concerts/25612829-mountain-goats-at-port-city-music-hall']
# ['9478034', '/concerts/25626149-mac-demarco-at-roseland-theater']
# ['9483194', '/concerts/25650094-blue-october-at-roseland-theater']
# ['9483958', '/concerts/25593959-ra-ra-riot-at-revolution-hall']
# ['9484056', '/concerts/25668089-maine-at-state-theatre']
# ['9484101', '/concerts/25666344-san-fermin-at-mississippi-studios']
# ['9485299', '/concerts/25613149-milk-carton-kids-at-state-theatre']
# ['9485369', '/concerts/25690494-dream-theater-at-arlene-schnitzer-concert-hall']
# ['9486475', '/concerts/25730484-puscifer-at-merrill-auditorium-portland-city-hall']
# ['9486816', '/concerts/25736204-tech-n']
# ['9489290', '/concerts/25615274-sharon-jones-and-the-dapkings-at-keller-auditorium']
# ['9491372', '/concerts/25589984-deer-tick-at-port-city-music-hall']
# ['9491373', '/concerts/25674084-enter-the-haggis-at-port-city-music-hall']
# ['9491374', '/concerts/25563824-ezra-furman-at-port-city-music-hall']
# ['9491375', '/concerts/25768299-maine-youth-rock-orchestra-at-port-city-music-hall']
# ['9491768', '/concerts/25798589-between-the-buried-and-me-at-state-theatre']
# ['9491796', '/concerts/25813144-between-the-buried-and-me-at-roseland-theater']
# ['9500582', '/concerts/25821864-white-denim-at-doug-fir-lounge']
# ['9501172', '/concerts/25865334-miike-snow-at-roseland-theater']
# ['9501270', '/concerts/25851244-parachute-at-port-city-music-hall']
# ['9501799', '/concerts/25716234-m']
# ['9501801', '/concerts/25716234-m']
# ['9501813', '/concerts/25859339-say-anything-at-wonder-ballroom']
# ['9501942', '/concerts/25553309-tommy-emmanuel-at-state-theatre']
# ['9503237', '/concerts/25891908-wonder-years-at-hawthorne-theatre']
# ['9507334', '/concerts/25931033-hunter-hayes-at-maine-state-pier']
# ['9507975', '/concerts/25932363-moe-at-wonder-ballroom']
# ['9508248', '/concerts/25944083-beirut-at-state-theatre']
# ['9509205', '/concerts/25932638-magic-man-at-wonder-ballroom']
# ['9509416', '/concerts/25932743-peter-hook-and-the-light-at-wonder-ballroom']
# ['9509741', '/concerts/25915738-boyce-avenue-at-wonder-ballroom']
# ['9509764', '/concerts/25929868-pete-yorn-at-star-theater']
# ['9510981', '/concerts/25991658-waka-flocka-flame-at-state-theatre']
# ['9511025', '/concerts/26007198-modest-mouse-at-moda-center-at-the-rose-quarter']
# ['9511027', '/concerts/25994443-arcs-at-roseland-theater']
# ['9511043', '/concerts/25994768-james-bay-at-roseland-theater']
# ['9511202', '/concerts/26022618-third-eye-blind-at-roseland-theater']
# ['9511216', '/concerts/26022608-yung-lean-at-hawthorne-theatre']
# ['9511311', '/concerts/25994278-summer-set-at-hawthorne-theatre']
# ['9511450', '/concerts/26009023-brian-wilson-at-arlene-schnitzer-concert-hall']
# ['9511549', '/concerts/25971503-john-mellencamp-at-merrill-auditorium-portland-city-hall']
# ['9511756', '/concerts/26035123-flatbush-zombies-at-roseland-theater']
# ['9511787', '/concerts/26006163-gogol-bordello-at-state-theatre']
# ['9511997', '/concerts/26019633-iggy-pop-at-keller-auditorium']
# ['9512321', '/concerts/26014668-geographer-at-hawthorne-theatre']
# ['9512363', '/concerts/25995033-brian-jonestown-massacre-at-wonder-ballroom']
# ['9512434', '/concerts/26008203-joy-formidable-at-wonder-ballroom']
# ['9512442', '/concerts/25951888-warren-haynes-at-aladdin-theater']
# ['9513666', '/concerts/25924888-gin-wigmore-at-star-theater']
# ['9513916', '/concerts/26058743-barenaked-ladies-at-maine-state-pier']
# ['9514236', '/concerts/26068453-santigold-at-wonder-ballroom']
# ['9514737', '/concerts/26083558-smashing-pumpkins-at-arlene-schnitzer-concert-hall']
# ['9516583', '/concerts/26096718-floating-points-at-doug-fir-lounge']
# ['9516585', '/concerts/26082503-shook-twins-at-doug-fir-lounge']
# ['9516586', '/concerts/26068128-kawehi-at-doug-fir-lounge']
# ['9517417', '/concerts/26090518-torche-at-port-city-music-hall']
# ['9517494', '/concerts/26064908-four-year-strong-at-port-city-music-hall']
# ['9517601', '/concerts/26082953-buzzcocks-at-revolution-hall']
# ['9517620', '/concerts/26119983-twiztid-at-hawthorne-theatre']
# ['9517708', '/concerts/26075223-tribal-seeds-at-port-city-music-hall']
# ['9519236', '/concerts/26118313-phish-at-cross-insurance-arena']
# ['9519284', '/concerts/26059113-lucius-at-wonder-ballroom']
# ['9520131', '/concerts/26082388-robert-cray-band-at-revolution-hall']
# ['9521443', '/concerts/26140918-neighbourhood-at-roseland-theater']
# ['9521453', '/concerts/26138903-leon-bridges-at-state-theatre']
# ['9521469', '/concerts/26119588-andrew-bird-at-arlene-schnitzer-concert-hall']
# ['9521580', '/concerts/26128783-somo-at-state-theatre']
# ['9521674', '/concerts/26134618-lumineers-at-arlene-schnitzer-concert-hall']
# ['9522179', '/concerts/26136868-bruce-springsteen-at-moda-center-at-the-rose-quarter']
# ['9522357', '/concerts/26138623-josh-turner-at-maine-state-pier']
# ['9522562', '/concerts/26152464-lamb-of-god-at-state-theatre']
# ['9523989', '/concerts/26154539-lukas-graham-at-doug-fir-lounge']
# ['9527298', '/concerts/26207829-leon-russell-at-aladdin-theater']
# ['9527397', '/concerts/26154704-joan-osborne-at-aladdin-theater']
# ['9527848', '/concerts/25957843-brit-floyd-at-arlene-schnitzer-concert-hall']
# ['9527952', '/concerts/26145474-dilly-dally-at-doug-fir-lounge']
# ['9527953', '/concerts/26189999-lily-and-madeleine-at-doug-fir-lounge']
# ['9527954', '/concerts/26220264-pup-at-doug-fir-lounge']
# ['9528654', '/concerts/26162679-sam-beam-at-aladdin-theater']
# ['9529361', '/concerts/25984043-savages-at-wonder-ballroom']
# ['9529521', '/concerts/25858584-m-ward-at-port-city-music-hall']
# ['9530316', '/concerts/26274449-paul-simon-at-arlene-schnitzer-concert-hall']
# ['9530326', '/concerts/26277399-atlas-genius-at-hawthorne-theatre']
# ['9530569', '/concerts/25945463-pegboard-nerds-at-euphoria-nightclub']
# ['9531322', '/concerts/26289249-slightly-stoopid-at-maine-state-pier']
# ['9531386', '/concerts/26263499-peter-wolf-at-port-city-music-hall']
# ['9531525', '/concerts/26154889-years-and-years-at-roseland-theater']
# ['9531547', '/concerts/26289154-whitesnake-at-maine-state-pier']
# ['9531782', '/concerts/26275164-goo-goo-dolls-at-maine-state-pier']
# ['9531915', '/concerts/26252729-hillsong-united-at-cross-insurance-arena']
# ['9531917', '/concerts/26259434-hillsong-united-at-moda-center-at-the-rose-quarter']
# ['9532250', '/concerts/26284084-zhu-at-roseland-theater']
# ['9532256', '/concerts/25995078-kaleo-at-mississippi-studios']
# ['9532367', '/concerts/26275174-band-perry-at-maine-state-pier']
# ['9533026', '/concerts/26254089-yuna-at-doug-fir-lounge']
# ['9534141', '/concerts/25971543-lapsley-at-doug-fir-lounge']
# ['9534262', '/concerts/26347134-macklemore-and-ryan-lewis-at-portland-veterans-memorial-coliseum']
# ['9534362', '/concerts/26341074-flight-of-the-conchords-at-keller-auditorium']
# ['9534610', '/concerts/26342804-chelsea-wolfe-at-revolution-hall']
# ['9534732', '/concerts/26290894-damien-jurado-at-doug-fir-lounge']
# ['9535325', '/concerts/26348949-blaqk-audio-at-doug-fir-lounge']
# ['9535389', '/concerts/26364004-mutual-benefit-at-doug-fir-lounge']
# ['9535815', '/concerts/26289014-jackson-browne-at-maine-state-pier']
# ['9536015', '/concerts/25637304-bag-raiders-at-doug-fir-lounge']
# ['9536205', '/concerts/26344119-kills-at-roseland-theater']
# ['9536221', '/concerts/26364344-streetlight-manifesto-at-wonder-ballroom']
# ['9536363', '/concerts/26347359-boy-and-bear-at-port-city-music-hall']
# ['9536469', '/concerts/26348929-mayer-hawthorne-at-revolution-hall']
# ['9536686', '/concerts/26247444-frightened-rabbit-at-wonder-ballroom']
# ['9537249', '/concerts/26082528-sza-at-wonder-ballroom']
# ['9537818', '/concerts/26311069-yeasayer-at-wonder-ballroom']
# ['9537936', '/concerts/26402704-joshua-radin-at-aladdin-theater']
# ['9538643', '/concerts/26424774-']
# ['9539111', '/concerts/26450949-paul-mccartney-at-moda-center-at-the-rose-quarter']
# ['9539245', '/concerts/26390474-bonnie-raitt-at-maine-state-pier']
# ['9539302', '/concerts/26438879-melissa-etheridge-at-maine-state-pier']
# ['9539668', '/concerts/26424534-emblem']
# ['9542312', '/concerts/26154874-wild-nothing-at-doug-fir-lounge']
# ['9542318', '/concerts/25993993-chairlift-at-mississippi-studios']
# ['9542394', '/concerts/25810604-max-creek-at-port-city-music-hall']
#   event_id  ticket_vendor    face_value        sold_out sk_artist_id
# 0  9152782   Ticketmaster        $39.50               0        69685
# 1  9352311   Ticketmaster        $24.95               0       410449
# 2  9367549  NoVendorClass  NoPriceClass  NoSoldOutClass       309236
# 3  9372111            AXS  NoPriceClass               1       455175
# 4  9381633      NoResults     NoResults       NoResults    NoResults

# %% [markdown]
# ## Join FaceValue Dataframe with original Dataframe

# %%
# Join FaceValue dataframe with original TicketData data frame
backup = TicketData.copy() # Make a backup of original dataframe before join just in case something goes wrong.
TicketData = TicketData.join(FaceValue_df, how='left', rsuffix='_fv')
del TicketData['event_id_fv']
TicketData.head()
# Out:
#   event_id                      date         artist  \
# 0  9152782  2016-05-17T20:30:00-0700        The Who
# 1  9352311  2016-07-03T20:00:00-0700  Janet Jackson
# 2  9367549  2016-04-14T20:00:00-0700  Gary Clark Jr
# 3  9372111  2016-03-14T20:00:00-0700      Disturbed
# 4  9381633  2016-03-31T19:30:00-0700      Underoath
#
#                              venue min_price max_price total_postings  \
# 0  Moda Center at the Rose Quarter     68.17     902.0             58
# 1  Moda Center at the Rose Quarter      55.6     500.0            124
# 2                 Roseland Theater     74.26    199.88             30
# 3                 Roseland Theater     77.82   5555.55             14
# 4      McMenamins Crystal Ballroom     57.83     199.0             10
#
#   total_tickets      city state  ticket_vendor    face_value        sold_out  \
# 0         170.0  Portland    OR   Ticketmaster        $39.50               0
# 1         371.0  Portland    OR   Ticketmaster        $24.95               0
# 2         128.0  Portland    OR  NoVendorClass  NoPriceClass  NoSoldOutClass
# 3          63.0  Portland    OR            AXS  NoPriceClass               1
# 4          70.0  Portland    OR      NoResults     NoResults       NoResults
#
#   sk_artist_id
# 0        69685
# 1       410449
# 2       309236
# 3       455175
# 4    NoResults

# %% [markdown]
# ## Calculate number of days from present until each show

# %%
# Calculate number of days from now until the show for each row.
TicketData['days_to_show'] = TicketData['date'].apply(GetNumberOfDaysUntilDate)
TicketData.head()
# Out:
#   event_id                      date         artist  \
# 0  9152782  2016-05-17T20:30:00-0700        The Who
# 1  9352311  2016-07-03T20:00:00-0700  Janet Jackson
# 2  9367549  2016-04-14T20:00:00-0700  Gary Clark Jr
# 3  9372111  2016-03-14T20:00:00-0700      Disturbed
# 4  9381633  2016-03-31T19:30:00-0700      Underoath
#
#                              venue min_price max_price total_postings  \
# 0  Moda Center at the Rose Quarter     68.17     902.0             58
# 1  Moda Center at the Rose Quarter      55.6     500.0            124
# 2                 Roseland Theater     74.26    199.88             30
# 3                 Roseland Theater     77.82   5555.55             14
# 4      McMenamins Crystal Ballroom     57.83     199.0             10
#
#   total_tickets      city state  ticket_vendor    face_value        sold_out  \
# 0         170.0  Portland    OR   Ticketmaster        $39.50               0
# 1         371.0  Portland    OR   Ticketmaster        $24.95               0
# 2         128.0  Portland    OR  NoVendorClass  NoPriceClass  NoSoldOutClass
# 3          63.0  Portland    OR            AXS  NoPriceClass               1
# 4          70.0  Portland    OR      NoResults     NoResults       NoResults
#
#   sk_artist_id  days_to_show
# 0        69685            65
# 1       410449           112
# 2       309236            32
# 3       455175             1
# 4    NoResults            18

# %% [markdown]
# ## Check Results

# %%
no_sk_results = TicketData[TicketData['face_value'] == 'NoResults']['venue'].count()
no_fv_sk = TicketData[TicketData['face_value'] == 'NoPriceClass']['venue'].count()
no_fv = no_sk_results + no_fv_sk
total_events = TicketData['event_id'].count()
pct_fv = (1 - float(no_fv)/float(total_events))*100

print("Number of events with no SK search results: \n%d" % no_sk_results)
print("Number of events found in SK but without FV prices in SK: \n%d" % no_fv_sk)
print("Total events with no face value price found: \n%d" % no_fv)
print("Total number of events: \n%d" % total_events)
print("Percent of events with FV's: \n%d" % pct_fv)
print "\nVenue value counts with no search results in SK: "
print TicketData[TicketData['face_value'] == 'NoResults']['venue'].value_counts()
# Out:
# Number of events with no SK search results:
# 50
# Number of events found in SK but without FV prices in SK:
# 58
# Total events with no face value price found:
# 108
# Total number of events:
# 207
# Percent of events with FV's:
# 47
#
# Venue value counts with no search results in SK:
# McMenamins Crystal Ballroom        21
# Thompsons Point                     7
# Roseland Theater                    4
# Hawthorne Theatre                   3
# Dantes                              3
# Moda Center at the Rose Quarter     2
# Maine State Pier                    2
# Holocene                            1
# Wonder Ballroom                     1
# Port City Music Hall                1
# Doug Fir Lounge                     1
# Cross Insurance Arena               1
# Asylum Maine                        1
# Merrill Auditorium                  1
# Arlene Schnitzer Hall               1
# Name: venue, dtype: int64

# %% [markdown]
# ## Write Pre-EchoNest Dataframe to CSV (as a backup)

# %%
# Write resulting dataframe to CSV.
TicketData.to_csv(path_or_buf="Data/Mid_Pipeline_Data/PreEchonest_TicketData_"+file_suffix+".csv", index=False)

# %% [markdown]
# ## Get Echonest Info for Artists

# %%
# Get current Echonest rate limit and set sleep time so that we can wait an appropriate time between EN API calls
rate_limit = GetEchonestRateLimit()
sleep_time = (60/rate_limit) - 0.4 # subtract 0.4 seconds since that's (roughly) how long each call takes
print("Echonest rate limit = %s and sleep_time = %s \n" % (rate_limit, sleep_time))
# Out:
# Echonest rate limit = 20 and sleep_time = 2.6

# %%
# Only include SK IDs for events where we actually found a real face value for the tickets.
list_of_sk_artist_ids = TicketData[(TicketData['face_value'] != 'NoPriceClass') 
           & (TicketData['face_value'] != 'NoResults')]['sk_artist_id']
# Get rid of duplicate SK IDs to save Echonest API calls
list_of_sk_artist_ids = set(list_of_sk_artist_ids)
print("Number of unique artist IDs in list_of_sk_artist_ids: %d" % len(list_of_sk_artist_ids))
# Out:
# Number of unique artist IDs in list_of_sk_artist_ids: 95

# %%
# Get Echonest data for each SK artist ID (TIME CONSUMING FOR LARGE LISTS OF SK ARTIST IDS):
echonest_artist_info_list = []
for artist_id in list_of_sk_artist_ids:
    if artist_id == None:
        continue # move on if we couldn't get a songkick id for an artist
    echonest_info_list = GetEchonestInfo(artist_id)
    echonest_artist_info_list.append(echonest_info_list)
    time.sleep(sleep_time) # Wait so that we don't go over the Echonest rate limit

print echonest_artist_info_list
# Out:
# [['360697', 523, 29, 13, 0.41068995643239187, 0.60537, 0.579694, 12], ['112691', 5241, 812, 61, 0.3919505709819035, 0.609446, 0.556979, 10], ['1183857', 1959, 48, 0, 0.604552420651678, 0.559962, 0.793894, 2], ['505217', 3058, 592, 36, 0.3482583069205712, 0.730461, 0.621415, 38], ['4154881', 1441, 472, 2, 0.3466214328199724, 0.503933, 0.418708, 40], ['181875', 6949, 2105, 92, 0.38991947795223525, 0.8101, 0.849666, 22], ['300543', 12883, 5418, 275, 0.3408289239239558, 0.810518, 0.743605, 46], ['172227', 1992, 228, 92, 0.39048458103611905, 0.678747, 0.627284, 24], ['355452', 1532, 126, 123, 0.39431198056175354, 0.707912, 0.670898, 10], ['235557', 1222, 227, 57, 0.3462206706357281, 0.671825, 0.548964, 16], ['528289', 247, 69, 23, 0.4341280813727815, 0.393634, 0.453525, 50], ['227030', 15104, 5188, 320, 0.3351500739096001, 0.829326, 0.774736, 51], ['6720604', 206, 6, 0, 0.4696494266424044, 0.501775, 0.565554, 7], ['59712', 992, 349, 14, 0.37327594100849004, 0.649055, 0.567765, 9], ['608550', 228, 37, 0, 0.4280020362602742, 0.610056, 0.608825, 12], ['553241', 479, 432, 19, 0.4173778589992091, 0.615103, 0.598724, 22], ['589804', 2714, 436, 90, 0.4200359893162661, 0.539433, 0.534639, 10], ['976211', 6063, 1776, 13, 0.42707395045850144, 0.769929, 0.835224, 14], ['630444', 79, 42, 1, 0.4761552672289627, 0.41082, 0.504837, 12], ['73973', 999, 86, 130, 0.41623998835332304, 0.638522, 0.621462, 28], ['216176', 232, 18, 8, 0.41279769689355084, 0.596615, 0.574393, 54], ['430868', 570, 333, 12, 0.3851883823012393, 0.663278, 0.601152, 21], ['NoRegexp', 'error_5', 'error_5', 'error_5', 'error_5', 'error_5', 'error_5', 'error_5'], ['4186126', 381, 111, 15, 0.4549994199304496, 0.512141, 0.556221, 5], ['46745', 5729, 2931, 123, 0.3218130011539002, 0.734903, 0.579851, 33], ['4665213', 1714, 349, 40, 0.5750904634134799, 0.445357, 0.639432, 5], ['3836411', 724, 109, 20, 0.5035243616998618, 0.458032, 0.569831, 7], ['578861', 893, 83, 11, 0.41372728051255425, 0.531711, 0.520564, 13], ['51843', 2284, 787, 62, 0.3282404598913963, 0.722503, 0.575742, 50], ['8068588', 447, 24, 1, 0.6548093250186046, 0.400897, 0.684904, 3], ['145102', 1007, 224, 64, 0.34746319361264844, 0.72721, 0.61564, 30], ['458141', 753, 205, 9, 0.4241148809454919, 0.449173, 0.474072, 29], ['2355020', 684, 44, 12, 0.48506769405989525, 0.456321, 0.547633, 10], ['399137', 1276, 196, 82, 0.37694532481118087, 0.565609, 0.499341, 12], ['3123851', 852, 266, 10, 0.5725633529624048, 0.586834, 0.78425, 7], ['398453', 537, 154, 37, 0.4228572215020871, 0.529346, 0.530184, 49], ['1077331', 399, 175, 11, 0.5094867319244379, 0.50701, 0.618196, 12], ['546803', 56, 3, 2, 0.46951403095462946, 0.39553, 0.490492, 21], ['1195278', 2286, 500, 58, 0.4191544927234303, 0.562696, 0.552757, 9], ['162633', 17, 19, 0, 0.3917543472277423, 0.313438, 0.409258, None], ['100819', 1877, 463, 72, 0.39323519503399934, 0.581703, 0.534238, 12], ['975813', 1610, 47, 7, 0.41358679089685324, 0.590688, 0.570008, 10], ['22900', 384, 82, 15, 0.42215910562936654, 0.593816, 0.584763, 14], ['9315', 223, 38, 3, 0.3939322080113532, 0.607437, 0.557938, 10], ['488253', 3642, 548, 276, 0.45567034953047575, 0.664594, 0.712874, 25], ['425237', 1256, 153, 5, 0.3979918512985334, 0.591405, 0.549148, 8], ['699966', 1060, 75, 0, 0.4699769912353551, 0.500253, 0.564706, 7], ['6008179', 61, 21, 2, 0.4844621465352863, 0.311886, 0.506108, 5], ['22090', 590, 255, 42, 0.4144240658110544, 0.637421, 0.617564, 18], ['525418', 5612, 390, 135, 0.4040795545058942, 0.744452, 0.743836, 15], ['474383', 1950, 470, 71, 0.43807099503817415, 0.67709, 0.701519, 17], ['825630', 1482, 1653, 11, 0.6098640280524775, 0.615139, 0.874896, 11], ['4876678', 255, 56, 3, 0.39271062075906116, 0.370697, 0.410257, 16], ['424921', 611, 201, 31, 0.3621526044673349, 0.656447, 0.558207, 31], ['6439724', 181, 44, 0, 0.47337197024260913, 0.498185, 0.567092, 9], ['242996', 13, 5, 56, 0.5766377255391132, 0.340308, 0.602402, 6], ['598452', 1429, 280, 8, 0.4438013392162591, 0.534077, 0.560 ...

# %%
# Put echonest_artist_info_list into a dataframe to be joined with TicketData
en_artist_info_list_columns = ['sk_artist_id', 'num_blogs', 'num_news', 'num_reviews', 'discovery', 'familiarity',
                              'hotttnesss', 'num_years_active']
Echonest_artist_info_df = pd.DataFrame(echonest_artist_info_list, columns=en_artist_info_list_columns)
Echonest_artist_info_df.head(15)
# Out:
#    sk_artist_id num_blogs num_news num_reviews discovery familiarity  \
# 0        360697       523       29          13   0.41069     0.60537
# 1        112691      5241      812          61  0.391951    0.609446
# 2       1183857      1959       48           0  0.604552    0.559962
# 3        505217      3058      592          36  0.348258    0.730461
# 4       4154881      1441      472           2  0.346621    0.503933
# 5        181875      6949     2105          92  0.389919      0.8101
# 6        300543     12883     5418         275  0.340829    0.810518
# 7        172227      1992      228          92  0.390485    0.678747
# 8        355452      1532      126         123  0.394312    0.707912
# 9        235557      1222      227          57  0.346221    0.671825
# 10       528289       247       69          23  0.434128    0.393634
# 11       227030     15104     5188         320   0.33515    0.829326
# 12      6720604       206        6           0  0.469649    0.501775
# 13        59712       992      349          14  0.373276    0.649055
# 14       608550       228       37           0  0.428002    0.610056
#
#    hotttnesss num_years_active
# 0    0.579694               12
# 1    0.556979               10
# 2    0.793894                2
# 3    0.621415               38
# 4    0.418708               40
# 5    0.849666               22
# 6    0.743605               46
# 7    0.627284               24
# 8    0.670898               10
# 9    0.548964               16
# 10   0.453525               50
# 11   0.774736               51
# 12   0.565554                7
# 13   0.567765                9
# 14   0.608825               12

# %% [markdown]
# ## Merge EchoNest data with main TicketData dataframe

# %%
Joined_DF = pd.merge(TicketData, Echonest_artist_info_df, how='left', left_on='sk_artist_id', right_on='sk_artist_id')
Joined_DF.head()
# Out:
#   event_id                      date         artist  \
# 0  9152782  2016-05-17T20:30:00-0700        The Who
# 1  9352311  2016-07-03T20:00:00-0700  Janet Jackson
# 2  9367549  2016-04-14T20:00:00-0700  Gary Clark Jr
# 3  9372111  2016-03-14T20:00:00-0700      Disturbed
# 4  9381633  2016-03-31T19:30:00-0700      Underoath
#
#                              venue min_price max_price total_postings  \
# 0  Moda Center at the Rose Quarter     68.17     902.0             58
# 1  Moda Center at the Rose Quarter      55.6     500.0            124
# 2                 Roseland Theater     74.26    199.88             30
# 3                 Roseland Theater     77.82   5555.55             14
# 4      McMenamins Crystal Ballroom     57.83     199.0             10
#
#   total_tickets      city state       ...               sold_out sk_artist_id  \
# 0         170.0  Portland    OR       ...                      0        69685
# 1         371.0  Portland    OR       ...                      0       410449
# 2         128.0  Portland    OR       ...         NoSoldOutClass       309236
# 3          63.0  Portland    OR       ...                      1       455175
# 4          70.0  Portland    OR       ...              NoResults    NoResults
#
#   days_to_show num_blogs  num_news num_reviews discovery familiarity  \
# 0           65     16207      3483         184  0.272204    0.837273
# 1          112      6824      4132          59  0.360137    0.795111
# 2           32       NaN       NaN         NaN       NaN         NaN
# 3            1       NaN       NaN         NaN       NaN         NaN
# 4           18       NaN       NaN         NaN       NaN         NaN
#
#   hotttnesss num_years_active
# 0   0.645903               52
# 1   0.752127               43
# 2        NaN              NaN
# 3        NaN              NaN
# 4        NaN              NaN
#
# [5 rows x 22 columns]

# %%
# Count how many events in the Dataframe have actual face value data
fv_count = Joined_DF[(Joined_DF['face_value'] != 'NoPriceClass') 
           & (Joined_DF['face_value'] != 'NoResults')]['face_value'].count()
print("Number of events with real face vales: %s" % fv_count)
print("Total number of events: %s" % Joined_DF['event_id'].count())
# Out:
# Number of events with real face vales: 99
# Total number of events: 207

# %%
# Optional Sanity Check: inspect SongKick and Echonest data together 
Joined_DF[['artist', 'venue', 'city', 'ticket_vendor', 'face_value', 'sold_out', 'sk_artist_id',
          'num_blogs', 'num_news', 'discovery', 'hotttnesss', 'num_years_active']].head()
# Out:
#           artist                            venue      city  ticket_vendor  \
# 0        The Who  Moda Center at the Rose Quarter  Portland   Ticketmaster
# 1  Janet Jackson  Moda Center at the Rose Quarter  Portland   Ticketmaster
# 2  Gary Clark Jr                 Roseland Theater  Portland  NoVendorClass
# 3      Disturbed                 Roseland Theater  Portland            AXS
# 4      Underoath      McMenamins Crystal Ballroom  Portland      NoResults
#
#      face_value        sold_out sk_artist_id num_blogs num_news discovery  \
# 0        $39.50               0        69685     16207     3483  0.272204
# 1        $24.95               0       410449      6824     4132  0.360137
# 2  NoPriceClass  NoSoldOutClass       309236       NaN      NaN       NaN
# 3  NoPriceClass               1       455175       NaN      NaN       NaN
# 4     NoResults       NoResults    NoResults       NaN      NaN       NaN
#
#   hotttnesss num_years_active
# 0   0.645903               52
# 1   0.752127               43
# 2        NaN              NaN
# 3        NaN              NaN
# 4        NaN              NaN

# %% [markdown]
# ## Write Joined Dataframe to CSV

# %%
# Write resulting dataframe to CSV.
Joined_DF.to_csv(path_or_buf="Data/Metro_area_data/TicketData_"+file_suffix+".csv", index=False)
